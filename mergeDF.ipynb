# %%
import pickle
import pandas as pd
df: pd.DataFrame
df2: pd.DataFrame


with open("tt/testOutputBTVANoBottom.pkl", "rb") as file:
    df = pickle.load(file)

with open("testOutputBTVAWinnerFlip2.pkl", "rb") as file:
    df2 = pickle.load(file)

df = df.drop(df[df["risk_measure"] == "Winner change risk"].index)

df = pd.concat([df, df2])

with open("testOutputBTVA.pkl", "wb") as file:
    # Serialize the object and write it to the file
    pickle.dump(df, file)

# %%
df
# Out:
#                                                  input          voting_scheme  \
# 0    [[B, D, D, A, B], [A, C, A, B, D], [E, B, E, D...  Anti-plurality voting
# 1    [[C, E, D, D, A], [A, A, B, B, C], [B, C, E, E...  Anti-plurality voting
# 2    [[E, B, B, D, B], [C, E, A, C, D], [A, A, E, E...  Anti-plurality voting
# 3    [[C, D, A, E, C, A, B, C, E, B, B, D, C, A, A,...  Anti-plurality voting
# 4    [[C, D, E, B, E, E, C, D, D, A, C, B, B, B, C,...  Anti-plurality voting
# ..                                                 ...                    ...
# 427  [[A, B, E, F, H, D, J, E, B, E, J, F, F, E, H,...       Plurality voting
# 428  [[I, J, I, C, D, D, H, C, G, E, D, D, H, D, H,...       Plurality voting
# 429  [[F, H, B, A, H, C, B, F, I, H], [D, B, C, J, ...       Plurality voting
# 430  [[E, C, A, D, H, I, H, D, B, G], [J, B, F, E, ...       Plurality voting
# 431  [[I, I, J, F, C, G, E, A, J, E], [D, G, F, H, ...       Plurality voting
#
# ...
